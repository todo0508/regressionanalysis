# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.datasets import load_boston

clf = linear_model.LinearRegression()
system = pd.read_csv("api_server_2018_spring.csv", sep=",")
system.head()
#print(system.size)

#print(system.index.values)
#print(system.columns.values)
X = system.loc[:, ['cpu_total']].as_matrix()
Y = system["pvps_total"].as_matrix()

# 予測モデルを作成
clf.fit(X, Y)
 
# 回帰係数
print("回帰係数::"+str(clf.coef_))
 
# 切片 (誤差)
print("切片 (誤差)::"+str(clf.intercept_))
 
# 決定係数
print("決定係数::"+str(clf.score(X, Y)))
# Out:
# 回帰係数::[3.65884625]
# 切片 (誤差)::6.264107590969871
# 決定係数::0.9726086120766232
# /Users/hirokiariji/work/tmp/env/lib/python3.6/site-packages/scipy/linalg/basic.py:1226: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
import matplotlib.pyplot as plt
 
# 散布図
plt.scatter(X, Y)
 
# 回帰直線
plt.plot(X, clf.predict(X))

print("2台totalの時の回帰直線")
# Out:
# 2台totalの時の回帰直線

# %%
X = system.loc[:, ['Web227']].as_matrix()
Y = system["web227_pvps"].as_matrix()

# 予測モデルを作成
clf.fit(X, Y)
 
# 回帰係数
print("回帰係数::"+str(clf.coef_))
 
# 切片 (誤差)
print("切片 (誤差)::"+str(clf.intercept_))
 
# 決定係数
print("決定係数::"+str(clf.score(X, Y)))
# Out:
# 回帰係数::[3.34568198]
# 切片 (誤差)::7.544068121130209
# 決定係数::0.9616096134553608

# %%
import matplotlib.pyplot as plt
 
# 散布図
plt.scatter(X, Y)
 
# 回帰直線
plt.plot(X, clf.predict(X))

print("2台totalの時の回帰直線")
# Out:
# 2台totalの時の回帰直線

# %%
X = system.loc[:, ['web228']].as_matrix()
Y = system["web228_pvps"].as_matrix()

# 予測モデルを作成
clf.fit(X, Y)
 
# 回帰係数
print("回帰係数::"+str(clf.coef_))
 
# 切片 (誤差)
print("切片 (誤差)::"+str(clf.intercept_))
 
# 決定係数
print("決定係数::"+str(clf.score(X, Y)))
# Out:
# 回帰係数::[3.95694434]
# 切片 (誤差)::-0.6749841571301118
# 決定係数::0.9550542258113993

# %%
import matplotlib.pyplot as plt
 
# 散布図
plt.scatter(X, Y)
 
# 回帰直線
plt.plot(X, clf.predict(X))

print("2台totalの時の回帰直線")
# Out:
# 2台totalの時の回帰直線
