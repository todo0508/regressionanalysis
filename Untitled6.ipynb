# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.datasets import load_boston

clf = linear_model.LinearRegression()
system = pd.read_csv("api_pvps_05.csv", sep=",")
system.head()
#print(system.size)

#print(system.index.values)
#print(system.columns.values)
X = system.loc[:, ['PVPS']].as_matrix()
Y = system["Period"].as_matrix()

# 予測モデルを作成
clf.fit(X, Y)
 
# 回帰係数
print("回帰係数::"+str(clf.coef_))
 
# 切片 (誤差)
print("切片 (誤差)::"+str(clf.intercept_))
 
# 決定係数
print("決定係数::"+str(clf.score(X, Y)))
# Out:
# 回帰係数::[565.50929315]
# 切片 (誤差)::-121016.99675308005
# 決定係数::0.9379231010909058

# %%
import matplotlib.pyplot as plt
 
# 散布図
plt.scatter(X, Y)
 
# 回帰直線
plt.plot(X, clf.predict(X))

print("2台totalの時の回帰直線")
# Out:
# 2台totalの時の回帰直線
